# %%
import pandas as pd
import numpy as np
import mysql.connector as cnx
pd.set_option("display.max_rows", 4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-d06ed077e3fe> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import mysql.connector as cnx
#       4 pd.set_option("display.max_rows", 4)
#
# ModuleNotFoundError: No module named 'mysql'

# %%
data = pd.read_csv("C:/Users/nngao/OneDrive - Kemri Wellcome Trust/Personal/Narshion/H Drive/etag/EtagV2/Kesho/CSEC/CSEC_DATA_CLEAN.csv")
data
# Out:
#         unique_id   fname        lname  gender child_age     dob  disability  \
# 0     C38/01/2019   Fatma     Mohammed       2     16yrs  2003.0           0
# 1     C77/01/2019   Maria      Musyoka       2     16yrs  2003.0           0
# ..            ...     ...          ...     ...       ...     ...         ...
# 249  C267/08/2019  Samuel        Oduor       1     17yrs  2002.0           0
# 250  C268/08/2019   Shani  Zawadi Alex       2     17yrs  2002.0           0
#
#          date_intake  intake_quarter  county  ...  parent_guard_names  \
# 0        21 Jan,2019               2       2  ...      Ahmed Mohammed
# 1        21 Jan,2019               2       2  ...      Jackline Akumu
# ..               ...             ...     ...  ...                 ...
# 249  2nd August,2019               4       3  ...               Oduor
# 250  2nd August,2019               4       3  ...                 NaN
#
#     parent_guard_relationship  parent_guard_id  parent_guard_contacts  \
# ...

# %%
# Write to database now
cnx.connect(user='root', password='',
                              host='127.0.0.1',
                              database='csec')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-de8fa87fd9cb> in <module>
#       1 # Write to database now
# ----> 2 cnx.connect(user='root', password='',
#       3                               host='127.0.0.1',
#       4                               database='csec')
#
# NameError: name 'cnx' is not defined

# %%
# !pip install mysql
# Out:
# ...
#   Stored in directory: C:\Users\nngao\AppData\Local\pip\Cache\wheels\4f\10\3f\4930effd0320769375b5094e279cb0e4a4c10a7e5811b58f8a
# Successfully built mysql
# ...
